# %%
import pandas as pd

# %%
df_1991 = pd.read_csv('IDH_1991.csv', encoding="latin1", sep = ';')

# %%
df_1991
# Out:
#      Ordem segundo o IDH Bairro ou grupo de bairros  \
# 0                      1                      Gávea
# 1                      2            Jardim Botânico
# 2                      3                    Ipanema
# 3                      4                     Leblon
# 4                      5                    Humaitá
# ..                   ...                        ...
# 121                  122                    Rocinha
# 122                  123                 Manguinhos
# 123                  124                       Maré
# 124                  125         Complexo do Alemão
# 125                  126     Acari, Parque Colúmbia
#
#     Esperança de vida ao nascer (em anos)  \
# 0                                   75,11
# 1                                   73,67
# 2                                      74
# 3                                   73,67
# 4                                    72,8
# ..                                    ...
# 121                                 65,15
# 122                                 62,32
# 123                                 62,71
# 124                                 62,36
# 125                                 60,29
#
#     Taxa de alfabetização de adultos (%) Taxa bruta de frequência escolar (%)  \
# 0                                  97,25                               100,64
# 1                                  97,81                                95,24
# 2                                  96,98                                93,95
# 3                                  97,49                                92,23
# 4                                  97,93                               102,67
# ..                                   ...                                  ...
# 121                                81,49                                54,47
# 122                                85,92                                62,98
# 123                                83,31                                60,57
# 124                                 83,6                                56,52
# 125                                86,21                                60,57
#
#     Renda per capita (em R$ de 2000) Índice de Longevidade (IDH-L)  \
# 0                             1796,1                         0,835
# 1                            1620,82                         0,811
# 2                            1606,88                         0,817
# 3                            1589,11                         0,811
# 4                            1422,01                         0,797
# ..                               ...                           ...
# 121                           170,57                         0,669
# 122                           157,26                         0,622
# 123                           156,26                         0,628
# 124                           144,01                         0,623
# 125                           147,17                         0,588
#
#     Índice de Educação (IDH-E) Índice de Renda (IDH-R)  \
# 0                        0,982                       1
# 1                         0,97                       1
# 2                         0,96                       1
# 3                        0,957                       1
# 4                        0,986                   0,985
# ..                         ...                     ...
# 121                      0,725                   0,631
# 122                      0,783                   0,617
# 123                      0,757                   0,616
# 124                      0,746                   0,602
# 125                      0,777                   0,606
#
#     Índice de Desenvolvimento Humano Municipal (IDH)
# 0                                              0,939
# 1                                              0,927
# 2                                              0,925
# 3                                              0,923
# 4                                              0,923
# ..                                               ...
# 121                                            0,675
# 122                                            0,674
# 123                                            0,667
# 124                                            0,657
# 125                                            0,657
#
# [126 rows x 10 columns]

# %%
df_1991.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 10 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Ordem segundo o IDH                               126 non-null    int64
#  1   Bairro ou grupo de bairros                        126 non-null    object
#  2   Esperança de vida ao nascer (em anos)             126 non-null    object
#  3   Taxa de alfabetização de adultos (%)              126 non-null    object
#  4   Taxa bruta de frequência escolar (%)              126 non-null    object
#  5   Renda per capita (em R$ de 2000)                  126 non-null    object
#  6   Índice de Longevidade (IDH-L)                     126 non-null    object
#  7   Índice de Educação (IDH-E)                        126 non-null    object
#  8   Índice de Renda (IDH-R)                           126 non-null    object
#  9   Índice de Desenvolvimento Humano Municipal (IDH)  126 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 10.0+ KB

# %%
df_1991.isnull().sum()
# Out:
# Ordem segundo o IDH                                 0
# Bairro ou grupo de bairros                          0
# Esperança de vida ao nascer (em anos)               0
# Taxa de alfabetização de adultos (%)                0
# Taxa bruta de frequência escolar (%)                0
# Renda per capita (em R$ de 2000)                    0
# Índice de Longevidade (IDH-L)                       0
# Índice de Educação (IDH-E)                          0
# Índice de Renda (IDH-R)                             0
# Índice de Desenvolvimento Humano Municipal (IDH)    0
# dtype: int64

# %%
df_1991 = df_1991.replace(',','.', regex=True)
df_1991
# Out:
#      Ordem segundo o IDH Bairro ou grupo de bairros  \
# 0                      1                      Gávea
# 1                      2            Jardim Botânico
# 2                      3                    Ipanema
# 3                      4                     Leblon
# 4                      5                    Humaitá
# ..                   ...                        ...
# 121                  122                    Rocinha
# 122                  123                 Manguinhos
# 123                  124                       Maré
# 124                  125         Complexo do Alemão
# 125                  126     Acari. Parque Colúmbia
#
#     Esperança de vida ao nascer (em anos)  \
# 0                                   75.11
# 1                                   73.67
# 2                                      74
# 3                                   73.67
# 4                                    72.8
# ..                                    ...
# 121                                 65.15
# 122                                 62.32
# 123                                 62.71
# 124                                 62.36
# 125                                 60.29
#
#     Taxa de alfabetização de adultos (%) Taxa bruta de frequência escolar (%)  \
# 0                                  97.25                               100.64
# 1                                  97.81                                95.24
# 2                                  96.98                                93.95
# 3                                  97.49                                92.23
# 4                                  97.93                               102.67
# ..                                   ...                                  ...
# 121                                81.49                                54.47
# 122                                85.92                                62.98
# 123                                83.31                                60.57
# 124                                 83.6                                56.52
# 125                                86.21                                60.57
#
#     Renda per capita (em R$ de 2000) Índice de Longevidade (IDH-L)  \
# 0                             1796.1                         0.835
# 1                            1620.82                         0.811
# 2                            1606.88                         0.817
# 3                            1589.11                         0.811
# 4                            1422.01                         0.797
# ..                               ...                           ...
# 121                           170.57                         0.669
# 122                           157.26                         0.622
# 123                           156.26                         0.628
# 124                           144.01                         0.623
# 125                           147.17                         0.588
#
#     Índice de Educação (IDH-E) Índice de Renda (IDH-R)  \
# 0                        0.982                       1
# 1                         0.97                       1
# 2                         0.96                       1
# 3                        0.957                       1
# 4                        0.986                   0.985
# ..                         ...                     ...
# 121                      0.725                   0.631
# 122                      0.783                   0.617
# 123                      0.757                   0.616
# 124                      0.746                   0.602
# 125                      0.777                   0.606
#
#     Índice de Desenvolvimento Humano Municipal (IDH)
# 0                                              0.939
# 1                                              0.927
# 2                                              0.925
# 3                                              0.923
# 4                                              0.923
# ..                                               ...
# 121                                            0.675
# 122                                            0.674
# 123                                            0.667
# 124                                            0.657
# 125                                            0.657
#
# [126 rows x 10 columns]

# %%
df_1991.describe(include='all').T
# Out:
#                                                   count unique     top freq  \
# Ordem segundo o IDH                               126.0    NaN     NaN  NaN
# Bairro ou grupo de bairros                          126    126   Gávea    1
# Esperança de vida ao nascer (em anos)               126     85   67.74    5
# Taxa de alfabetização de adultos (%)                126    119   94.19    3
# Taxa bruta de frequência escolar (%)                126    124   60.57    2
# Renda per capita (em R$ de 2000)                    126    126  1796.1    1
# Índice de Longevidade (IDH-L)                       126     74   0.712    5
# Índice de Educação (IDH-E)                          126     92   0.915    3
# Índice de Renda (IDH-R)                             126    103       1    6
# Índice de Desenvolvimento Humano Municipal (IDH)    126     98   0.794    5
#
#                                                   mean        std  min    25%  \
# Ordem segundo o IDH                               63.5  36.517119  1.0  32.25
# Bairro ou grupo de bairros                         NaN        NaN  NaN    NaN
# Esperança de vida ao nascer (em anos)              NaN        NaN  NaN    NaN
# Taxa de alfabetização de adultos (%)               NaN        NaN  NaN    NaN
# Taxa bruta de frequência escolar (%)               NaN        NaN  NaN    NaN
# Renda per capita (em R$ de 2000)                   NaN        NaN  NaN    NaN
# Índice de Longevidade (IDH-L)                      NaN        NaN  NaN    NaN
# Índice de Educação (IDH-E)                         NaN        NaN  NaN    NaN
# Índice de Renda (IDH-R)                            NaN        NaN  NaN    NaN
# Índice de Desenvolvimento Humano Municipal (IDH)   NaN        NaN  NaN    NaN
#
#                                                    50%    75%    max
# Ordem segundo o IDH                               63.5  94.75  126.0
# Bairro ou grupo de bairros                         NaN    NaN    NaN
# Esperança de vida ao nascer (em anos)              NaN    NaN    NaN
# Taxa de alfabetização de adultos (%)               NaN    NaN    NaN
# Taxa bruta de frequência escolar (%)               NaN    NaN    NaN
# Renda per capita (em R$ de 2000)                   NaN    NaN    NaN
# Índice de Longevidade (IDH-L)                      NaN    NaN    NaN
# Índice de Educação (IDH-E)                         NaN    NaN    NaN
# Índice de Renda (IDH-R)                            NaN    NaN    NaN
# Índice de Desenvolvimento Humano Municipal (IDH)   NaN    NaN    NaN

# %%
coluna_object = df_1991.select_dtypes(include=['object']).columns
coluna_object = coluna_object.drop(['Bairro ou grupo de bairros'])
for coluna in coluna_object:
    df_1991[coluna] = pd.to_numeric(df_1991[coluna], errors='coerce')
print(df_1991.dtypes)
# Out:
# Ordem segundo o IDH                                   int64
# Bairro ou grupo de bairros                           object
# Esperança de vida ao nascer (em anos)               float64
# Taxa de alfabetização de adultos (%)                float64
# Taxa bruta de frequência escolar (%)                float64
# Renda per capita (em R$ de 2000)                    float64
# Índice de Longevidade (IDH-L)                       float64
# Índice de Educação (IDH-E)                          float64
# Índice de Renda (IDH-R)                             float64
# Índice de Desenvolvimento Humano Municipal (IDH)    float64
# dtype: object
